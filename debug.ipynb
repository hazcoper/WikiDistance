# %%
myDict = {'continue': {'plcontinue': '23033|0|1975_Portuguese_Constituent_Assembly_election', 'continue': '||'}, 'query': {'pages': {'23033': {'pageid': 23033, 'ns': 0, 'title': 'Portugal', 'links': [{'ns': 0, 'title': '.pt'}, {'ns': 0, 'title': '10th CPLP Summit'}, {'ns': 0, 'title': '11th CPLP Summit'}, {'ns': 0, 'title': '12th CPLP Summit'}, {'ns': 0, 'title': '1383–85 Crisis'}, {'ns': 0, 'title': '1383–85 Portuguese interregnum'}, {'ns': 0, 'title': '1755 Lisbon earthquake'}, {'ns': 0, 'title': '1761 Lisbon earthquake'}, {'ns': 0, 'title': '1890 British Ultimatum'}, {'ns': 0, 'title': '1966 FIFA World Cup'}]}}}}

# %%
from pprint import pprint

pprint(myDict)
# Out:
# {'continue': {'continue': '||',
#               'plcontinue': '23033|0|1975_Portuguese_Constituent_Assembly_election'},
#  'query': {'pages': {'23033': {'links': [{'ns': 0, 'title': '.pt'},
#                                          {'ns': 0, 'title': '10th CPLP Summit'},
#                                          {'ns': 0, 'title': '11th CPLP Summit'},
#                                          {'ns': 0, 'title': '12th CPLP Summit'},
#                                          {'ns': 0, 'title': '1383–85 Crisis'},
#                                          {'ns': 0,
#                                           'title': '1383–85 Portuguese '
#                                                    'interregnum'},
#                                          {'ns': 0,
#                                           'title': '1755 Lisbon earthquake'},
#                                          {'ns': 0,
#                                           'title': '1761 Lisbon earthquake'},
# ...

# %%
myList = []

print(myDict.keys())
print(myDict["query"].keys())
print(myDict["query"]["pages"].keys())

current = myDict["query"]["pages"]
print(current[list(current)[0]].keys())

current = current[list(current)[0]]["links"]
print(current)
print(type(current))

print(myDict["query"]["pages"][list(myDict["query"]["pages"])[0]]["links"])
# Out:
# dict_keys(['continue', 'query'])
# dict_keys(['pages'])
# dict_keys(['23033'])
# dict_keys(['pageid', 'ns', 'title', 'links'])
# [{'ns': 0, 'title': '.pt'}, {'ns': 0, 'title': '10th CPLP Summit'}, {'ns': 0, 'title': '11th CPLP Summit'}, {'ns': 0, 'title': '12th CPLP Summit'}, {'ns': 0, 'title': '1383–85 Crisis'}, {'ns': 0, 'title': '1383–85 Portuguese interregnum'}, {'ns': 0, 'title': '1755 Lisbon earthquake'}, {'ns': 0, 'title': '1761 Lisbon earthquake'}, {'ns': 0, 'title': '1890 British Ultimatum'}, {'ns': 0, 'title': '1966 FIFA World Cup'}]
# <class 'list'>
# [{'ns': 0, 'title': '.pt'}, {'ns': 0, 'title': '10th CPLP Summit'}, {'ns': 0, 'title': '11th CPLP Summit'}, {'ns': 0, 'title': '12th CPLP Summit'}, {'ns': 0, 'title': '1383–85 Crisis'}, {'ns': 0, 'title': '1383–85 Portuguese interregnum'}, {'ns': 0, 'title': '1755 Lisbon earthquake'}, {'ns': 0, 'title': '1761 Lisbon earthquake'}, {'ns': 0, 'title': '1890 British Ultimatum'}, {'ns': 0, 'title': '1966 FIFA World Cup'}]

# %%
myValue = myDict["query"]["pages"][list(myDict["query"]["pages"])[0]]["links"]
print(myDict["query"]["pages"][list(myDict["query"]["pages"])[0]]["links"])
# Out:
# [{'ns': 0, 'title': '.pt'}, {'ns': 0, 'title': '10th CPLP Summit'}, {'ns': 0, 'title': '11th CPLP Summit'}, {'ns': 0, 'title': '12th CPLP Summit'}, {'ns': 0, 'title': '1383–85 Crisis'}, {'ns': 0, 'title': '1383–85 Portuguese interregnum'}, {'ns': 0, 'title': '1755 Lisbon earthquake'}, {'ns': 0, 'title': '1761 Lisbon earthquake'}, {'ns': 0, 'title': '1890 British Ultimatum'}, {'ns': 0, 'title': '1966 FIFA World Cup'}]

# %%
myList = [x["title"] for x in myValue]

# %%
print(myList)
# Out:
# ['.pt', '10th CPLP Summit', '11th CPLP Summit', '12th CPLP Summit', '1383–85 Crisis', '1383–85 Portuguese interregnum', '1755 Lisbon earthquake', '1761 Lisbon earthquake', '1890 British Ultimatum', '1966 FIFA World Cup']

# %%
import json

with open('myDict.json') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-8cfaedc1b46c> in <module>
#       2
#       3 with open('myDict.json') as json_file:
# ----> 4     data = json.load(json_file)
#       5
#
# /usr/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
print(len(list(data)))
# Out:
# dict_keys(['Portugal', '.pt', '10th CPLP Summit', '11th CPLP Summit', '12th CPLP Summit', '1383–85 Crisis', '1383–85 Portuguese interregnum', '1755 Lisbon earthquake', '1761 Lisbon earthquake', '1890 British Ultimatum', '1966 FIFA World Cup', '1975 Portuguese Constituent Assembly election', '1976 Portuguese legislative election', '1989 FIFA World Youth Championship', '1991 FIFA World Youth Championship', '1st CPLP Summit', '2001 Portuguese presidential election', '2004 European Football Championship', '2006 FIFA World Cup', '2007 Rugby World Cup', '2010–2014 Portuguese financial crisis', '2013 Portuguese local election', '2017 FIFA Confederations Cup', '2018–19 UEFA Nations League', '2019 UEFA Nations League Final', "28 May 1926 coup d'état", '2nd CPLP Summit', '2nd Lancers Regiment (Portugal)', '30th parallel north', '32nd meridian west', '3rd CPLP Summit', '42nd parallel north', '4th CPLP Summit', '5 October 1910 revolution', '5th CPLP Summit', '6th CPLP Summit', '6th meridian west
# ...

# %%
for key in data:
    print(len(data[key]["links"]), key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-27b3796d782d> in <module>
# ----> 1 for key in data:
#       2     print(len(data[key]["links"]), key)
#
# NameError: name 'data' is not defined
